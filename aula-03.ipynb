# %% [markdown]
# <img src='figures/logo.png'>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Onde-queremos-chegar?" data-toc-modified-id="Onde-queremos-chegar?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Onde queremos chegar?</a></span></li><li><span><a href="#O-que-nossos-dados-podem-nos-dizer?" data-toc-modified-id="O-que-nossos-dados-podem-nos-dizer?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>O que nossos dados podem nos dizer?</a></span><ul class="toc-item"><li><span><a href="#Vamos-explorar!" data-toc-modified-id="Vamos-explorar!-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Vamos explorar!</a></span><ul class="toc-item"><li><span><a href="#Qual-a-porcentagem-de-dados-faltantes?" data-toc-modified-id="Qual-a-porcentagem-de-dados-faltantes?-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Qual a porcentagem de dados faltantes?</a></span></li><li><span><a href="#Qual-a-distribuição-de-genero-dos-respondentes?" data-toc-modified-id="Qual-a-distribuição-de-genero-dos-respondentes?-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Qual a distribuição de genero dos respondentes?</a></span></li><li><span><a href="#Qual-a-distribuição-de-idade-por-genêro?" data-toc-modified-id="Qual-a-distribuição-de-idade-por-genêro?-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Qual a distribuição de idade por genêro?</a></span></li><li><span><a href="#Qual-a-distribuição-de-pais-de-origem?" data-toc-modified-id="Qual-a-distribuição-de-pais-de-origem?-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Qual a distribuição de pais de origem?</a></span></li><li><span><a href="#Qual-o-grau-de-formação-por-genêro?" data-toc-modified-id="Qual-o-grau-de-formação-por-genêro?-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Qual o grau de formação por genêro?</a></span></li><li><span><a href="#Qual-a-distribuição-de-carreiras-por-genêro?" data-toc-modified-id="Qual-a-distribuição-de-carreiras-por-genêro?-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Qual a distribuição de carreiras por genêro?</a></span></li><li><span><a href="#Qual-a-distribuição-de-experiência-por-genêro?" data-toc-modified-id="Qual-a-distribuição-de-experiência-por-genêro?-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Qual a distribuição de experiência por genêro?</a></span></li><li><span><a href="#Qual-a-distribuição-de-salário?" data-toc-modified-id="Qual-a-distribuição-de-salário?-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>Qual a distribuição de salário?</a></span></li></ul></li></ul></li><li><span><a href="#Referências" data-toc-modified-id="Referências-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Referências</a></span></li></ul></div>

# %% [markdown]
# # Onde queremos chegar?

# %% [markdown]
# <img src='figures/call_data_scientist.jpeg'>

# %% [markdown]
# **Entendimento do negócio**
#
# Antes de tudo, é importante entender o que deve ser feito. Algumas perguntas que podem nos ajudar são:

# %% [markdown]
# **1** Quais os Objetivos Gerais? Quais os Objetivos Especificos?
#
# **2** Qual é o problema que você está tentando resolver?
#
# **3** Por que ele é importante?
#
# **4** A partir de uma solução hipotética para o problema, como esta solução afetaria a empresa?
#
# **5** Temos capacidade de agir com base nessa solução ou também precisamos desenvolver essa habilidade?
#
# **6** Como vamos medir o sucesso da solução implementada (KPI)? O que faria dela um sucesso? Qual métrica será utilizada?

# %% [markdown]
#  <font color='#000080'>Objetivos Gerais</font>:
#         * Prever o salário das mulheres que trabalham com tecnlogia
#  <font color='#000080'>Objetivos Especificos</font>:
#         * Identificar se existe diferença entre o salario dos homens e das mulheres
#         * Identificar as variáveis que podem influenciar nessa diferença
#  <font color='#000080'>Problema</font>:
#         * Identificar se existe um viés de genêro no salário
#  <font color='#000080'>Porque ele é relevante</font>:
#         * A equidade de genêro é um dos Objetivos de Desenvolvimento Sustentável  da ONU
#
#  <font color='#000080'>Como essa solução afetaria a empresa</font>:
#          * Ao identificar que mulheres com as mesmas caracteristicas dos homens ganham menos, é preciso informar o RH e então propor políticas de equidade
#
#  <font color='#000080'>Temos capacidade de agir com base nessa solução</font>:
#          * Sim
#
#  <font color='#000080'>Como vamos medir o sucesso dessa solução</font>:
#          * Sucesso do metódo:
#              - AUC
#              - ROC
#          * Sucesso da solução:
#              - Implantação de novas políticas de remuneração

# %% [markdown]
# Algumas ferramentas úteis:
#
# * Mapa de stakeholders
# * ML Canvas
# * Mapa de Riscos e Mitigadores

# %% [markdown]
# # O que nossos dados podem nos dizer?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.font_manager import FontProperties


pd.set_option('display.max_columns', None)

# %%
df_choice = pd.read_csv('data/multipleChoiceResponses.csv',low_memory=False)

# %%
df_choice.head(2)
# Out:
#   Time from Start to Finish (seconds)                                      Q1  \
# 0               Duration (in seconds)  What is your gender? - Selected Choice
# 1                                 710                                  Female
#
#                                        Q1_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
#
#                             Q2                                         Q3  \
# 0  What is your age (# years)?  In which country do you currently reside?
# 1                        45-49                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
#
#                                                   Q5  \
# 0  Which best describes your undergraduate major?...
# 1                                              Other
#
#                                                   Q6  \
# 0  Select the title most similar to your current ...
# 1                                         Consultant
#
#                                        Q6_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
#
#                                                   Q7  \
# 0  In what industry is your current employer/cont...
# 1                                              Other
#
#                                        Q7_OTHER_TEXT  \
# 0  In what industry is your current employer/cont...
# 1                                                  0
#
#                                                   Q8  \
# 0  How many years of experience do you have in yo...
# 1                                                NaN
#
#                                                   Q9  \
# 0  What is your current yearly compensation (appr...
# 1                                                NaN
#
#                                                  Q10  \
# 0  Does your current employer incorporate machine...
# 1                                      I do not know
#
#                                           Q11_Part_1  \
# 0  Select any activities that make up an importan...
# 1  Analyze and understand data to influence produ...
#
#                                           Q11_Part_2  \
# 0  Select any activities that make up an importan...
# 1  Build and/or run a machine learning service th...
#
#                                           Q11_Part_3  \
# 0  Select any activities that make up an importan...
# 1  Build and/or run the data infrastructure that ...
#
#                                           Q11_Part_4  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
#
#                                           Q11_Part_5  \
# 0  Select any activities that make up an importan...
# 1  Do research that advances the state of the art...
#
#                                           Q11_Part_6  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
#
#                                           Q11_Part_7  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
#
#                                       Q11_OTHER_TEXT  \
# 0  Select any activities that make up an importan...
# 1                                                 -1
#
#                                  Q12_MULTIPLE_CHOICE  \
# 0  What is the primary tool that you use at work ...
# 1  Cloud-based data software & APIs (AWS, GCP, Az...
#
#                                      Q12_Part_1_TEXT  \
# 0  What is the primary tool that you use at work ...
# 1                                                 -1
#
#                                      Q12_Part_2_TEXT  \
# 0  What is the primary tool that you use at work ...
# 1                                                 -1
#
#                                      Q12_Part_3_TEXT  \
# 0  What is the primary tool that you use at work ...
# 1                                                 -1
#
#                                      Q12_Part_4_TEXT  \
# 0  What is the primary tool that you use at work ...
# 1                                                 -1
#
#                                      Q12_Part_5_TEXT  \
# 0  What is the primary tool that you use at work ...
# 1                                                  0
#
#                                       Q12_OTHER_TEXT  \
# 0  What is the primary tool that you use at work ...
# 1                                                 -1
#
#                                           Q13_Part_1  \
# 0  Which of the following integrated development ...
# 1                                    Jupyter/IPython
#
#                                           Q13_Part_2  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                           Q13_Part_3  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                           Q13_Part_4  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                           Q13_Part_5  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                           Q13_Part_6  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                           Q13_Part_7  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                           Q13_Part_8  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                           Q13_Part_9  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                          Q13_Part_10  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                          Q13_Part_11  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                          Q13_Part_12  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                          Q13_Part_13  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                          Q13_Part_14  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                          Q13_Part_15  \
# 0  Which of the following integrated development ...
# 1                                                NaN
#
#                                       Q13_OTHER_TEXT  \
# 0  Which of the following integrated development ...
# 1                                                 -1
#
#                                           Q14_Part_1  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_2  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_3  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_4  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_5  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_6  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_7  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_8  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                           Q14_Part_9  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                          Q14_Part_10  \
# 0  Which of the following hosted notebooks have y...
# 1                                               None
#
#                                          Q14_Part_11  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
#
#                                       Q14_OTHER_TEXT  \
# 0  Which of the following hosted notebooks have y...
# 1                                                 -1
#
#                                           Q15_Part_1  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
#
#                                           Q15_Part_2  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
#
#                                           Q15_Part_3  \
# 0  Which of the following cloud computing service...
# 1                                    Microsoft Azure
#
#                                           Q15_Part_4  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
#
#                                           Q15_Part_5  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
#
#                                           Q15_Part_6  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
#
#                                           Q15_Part_7  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
#
#                                       Q15_OTHER_TEXT  \
# 0  Which of the following cloud computing service...
# 1                                                 -1
#
#                                           Q16_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_3  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_4  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_5  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_6  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_7  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_8  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                           Q16_Part_9  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_10  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_11  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_12  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_13  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_14  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_15  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_16  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                          Q16_Part_17  \
# 0  What programming languages do you use on a reg...
# 1                                               None
#
#                                          Q16_Part_18  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
#
#                                       Q16_OTHER_TEXT  \
# 0  What programming languages do you use on a reg...
# 1                                                 -1
#
#                                                  Q17  \
# 0  What specific programming language do you use ...
# 1                                                NaN
#
#                                       Q17_OTHER_TEXT  \
# 0  What specific programming language do you use ...
# 1                                                 -1
#
#                                                  Q18  \
# 0  What programming language would you recommend ...
# 1                                             Python
#
#                                       Q18_OTHER_TEXT  \
# 0  What programming language would you recommend ...
# 1                                                 -1
#
#                                           Q19_Part_1  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_2  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_3  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_4  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_5  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_6  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_7  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_8  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                           Q19_Part_9  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_10  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_11  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_12  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_13  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_14  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_15  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_16  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_17  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                          Q19_Part_18  \
# 0  What machine learning frameworks have you used...
# 1                                               None
#
#                                          Q19_Part_19  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
#
#                                       Q19_OTHER_TEXT  \
# 0  What machine learning frameworks have you used...
# 1                                                 -1
#
#                                                  Q20  \
# 0  Of the choices that you selected in the previo...
# 1                                                NaN
#
#                                       Q20_OTHER_TEXT  \
# 0  Of the choices that you selected in the previo...
# 1                                                 -1
#
#                                           Q21_Part_1  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                           Q21_Part_2  \
# 0  What data visualization libraries or tools hav...
# 1                                         Matplotlib
#
#                                           Q21_Part_3  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                           Q21_Part_4  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                           Q21_Part_5  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                           Q21_Part_6  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                           Q21_Part_7  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                           Q21_Part_8  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                           Q21_Part_9  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                          Q21_Part_10  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                          Q21_Part_11  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                          Q21_Part_12  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                          Q21_Part_13  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
#
#                                       Q21_OTHER_TEXT  \
# 0  What data visualization libraries or tools hav...
# 1                                                 -1
#
#                                                  Q22  \
# 0  Of the choices that you selected in the previo...
# 1                                                NaN
#
#                                       Q22_OTHER_TEXT  \
# 0  Of the choices that you selected in the previo...
# 1                                                 -1
#
#                                                  Q23  \
# 0  Approximately what percent of your time at wor...
# 1                                      0% of my time
#
#                                                  Q24  \
# 0  How long have you been writing code to analyze...
# 1      I have never written code but I want to learn
#
#                                                  Q25  \
# 0  For how many years have you used machine learn...
# 1  I have never studied machine learning but plan...
#
#                                                 Q26  \
# 0  Do you consider yourself to be a data scientist?
# 1                                             Maybe
#
#                                           Q27_Part_1  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_2  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_3  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_4  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_5  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_6  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_7  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_8  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                           Q27_Part_9  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_10  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_11  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_12  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_13  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_14  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_15  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_16  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_17  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_18  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                          Q27_Part_19  \
# 0  Which of the following cloud computing product...
# 1                                               None
#
#                                          Q27_Part_20  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
#
#                                       Q27_OTHER_TEXT  \
# 0  Which of the following cloud computing product...
# 1                                                 -1
#
#                                           Q28_Part_1  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_2  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_3  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_4  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_5  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_6  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_7  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_8  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                           Q28_Part_9  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_10  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_11  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_12  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_13  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_14  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_15  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_16  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_17  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_18  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_19  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_20  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_21  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_22  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_23  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_24  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_25  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_26  \
# 0  Which of the following machine learning produc...
# 1                      Azure Machine Learning Studio
#
#                                          Q28_Part_27  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_28  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_29  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_30  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_31  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_32  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_33  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_34  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_35  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_36  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_37  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_38  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_39  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_40  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_41  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_42  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                          Q28_Part_43  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
#
#                                       Q28_OTHER_TEXT  \
# 0  Which of the following machine learning produc...
# 1                                                 -1
#
#                                           Q29_Part_1  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_2  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_3  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_4  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_5  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_6  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_7  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_8  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                           Q29_Part_9  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_10  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_11  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_12  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_13  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_14  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_15  \
# 0  Which of the following relational database pro...
# 1                                   Microsoft Access
#
#                                          Q29_Part_16  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_17  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_18  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_19  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_20  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_21  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_22  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_23  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_24  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_25  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_26  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_27  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                          Q29_Part_28  \
# 0  Which of the following relational database pro...
# 1                                                NaN
#
#                                       Q29_OTHER_TEXT  \
# 0  Which of the following relational database pro...
# 1                                                 -1
#
#                                           Q30_Part_1  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_2  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_3  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_4  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_5  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_6  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_7  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_8  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                           Q30_Part_9  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_10  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_11  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_12  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_13  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_14  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_15  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_16  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_17  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_18  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_19  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_20  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_21  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_22  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_23  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                          Q30_Part_24  \
# 0  Which of the following big data and analytics ...
# 1                                               None
#
#                                          Q30_Part_25  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
#
#                                       Q30_OTHER_TEXT  \
# 0  Which of the following big data and analytics ...
# 1                                                 -1
#
#                                           Q31_Part_1  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_2  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_3  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_4  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_5  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_6  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_7  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_8  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                           Q31_Part_9  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                          Q31_Part_10  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                          Q31_Part_11  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                          Q31_Part_12  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
#
#                                       Q31_OTHER_TEXT  \
# 0  Which types of data do you currently interact ...
# 1                                                 -1
#
#                                                  Q32  \
# 0  What is the type of data that you currently in...
# 1                                                NaN
#
#                                            Q32_OTHER  \
# 0  What is the type of data that you currently in...
# 1                                                 -1
#
#                                           Q33_Part_1  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_2  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_3  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_4  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_5  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_6  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_7  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_8  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                           Q33_Part_9  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                          Q33_Part_10  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                          Q33_Part_11  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
#
#                                       Q33_OTHER_TEXT  \
# 0  Where do you find public datasets? (Select all...
# 1                                                 -1
#
#                                           Q34_Part_1  \
# 0  During a typical data science project at work ...
# 1                                                NaN
#
#                                           Q34_Part_2  \
# 0  During a typical data science project at work ...
# 1                                                NaN
#
#                                           Q34_Part_3  \
# 0  During a typical data science project at work ...
# 1                                                NaN
#
#                                           Q34_Part_4  \
# 0  During a typical data science project at work ...
# 1                                                NaN
#
#                                           Q34_Part_5  \
# 0  During a typical data science project at work ...
# 1                                                NaN
#
#                                           Q34_Part_6  \
# 0  During a typical data science project at work ...
# 1                                                NaN
#
#                                       Q34_OTHER_TEXT  \
# 0  During a typical data science project at work ...
# 1                                                 -1
#
#                                           Q35_Part_1  \
# 0  What percentage of your current machine learni...
# 1                                                NaN
#
# ...
# 0  On which online platforms have you begun or co...
# 1                                                NaN
#
#                                          Q36_Part_11  \
# 0  On which online platforms have you begun or co...
# 1                                                NaN
#
#                                          Q36_Part_12  \
# 0  On which online platforms have you begun or co...
# 1                                                NaN
#
#                                          Q36_Part_13  \
# 0  On which online platforms have you begun or co...
# 1                                                NaN
#
#                                       Q36_OTHER_TEXT  \
# 0  On which online platforms have you begun or co...
# 1                                                 -1
#
#                                                  Q37  \
# 0  On which online platform have you spent the mo...
# 1                                                NaN
#
#                                       Q37_OTHER_TEXT  \
# 0  On which online platform have you spent the mo...
# 1                                                 -1
#
#                                           Q38_Part_1  \
# 0  Who/what are your favorite media sources that ...
# 1                                            Twitter
#
#                                           Q38_Part_2  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                           Q38_Part_3  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                           Q38_Part_4  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                           Q38_Part_5  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                           Q38_Part_6  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                           Q38_Part_7  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                           Q38_Part_8  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                           Q38_Part_9  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_10  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_11  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_12  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_13  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_14  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_15  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_16  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_17  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_18  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_19  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_20  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_21  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                          Q38_Part_22  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
#
#                                       Q38_OTHER_TEXT  \
# 0  Who/what are your favorite media sources that ...
# 1                                                 -1
#
#                                           Q39_Part_1  \
# 0  How do you perceive the quality of online lear...
# 1                                        Much better
#
#                                           Q39_Part_2  \
# 0  How do you perceive the quality of online lear...
# 1                                         Much worse
#
#                                                  Q40  \
# 0  Which better demonstrates expertise in data sc...
# 1  Independent projects are equally important as ...
#
#                                           Q41_Part_1  \
# 0  How do you perceive the importance of the foll...
# 1                                                NaN
#
#                                           Q41_Part_2  \
# 0  How do you perceive the importance of the foll...
# 1                                                NaN
#
#                                           Q41_Part_3  \
# 0  How do you perceive the importance of the foll...
# 1                                                NaN
#
#                                           Q42_Part_1  \
# 0  What metrics do you or your organization use t...
# 1                                                NaN
#
#                                           Q42_Part_2  \
# 0  What metrics do you or your organization use t...
# 1                                                NaN
#
#                                           Q42_Part_3  \
# 0  What metrics do you or your organization use t...
# 1                                                NaN
#
#                                           Q42_Part_4  \
# 0  What metrics do you or your organization use t...
# 1                                                NaN
#
#                                           Q42_Part_5  \
# 0  What metrics do you or your organization use t...
# 1                                                NaN
#
#                                       Q42_OTHER_TEXT  \
# 0  What metrics do you or your organization use t...
# 1                                                 -1
#
#                                                  Q43  \
# 0  Approximately what percent of your data projec...
# 1                                                NaN
#
#                                           Q44_Part_1  \
# 0  What do you find most difficult about ensuring...
# 1                                                NaN
#
#                                           Q44_Part_2  \
# 0  What do you find most difficult about ensuring...
# 1                                                NaN
#
#                                           Q44_Part_3  \
# 0  What do you find most difficult about ensuring...
# 1                                                NaN
#
#                                           Q44_Part_4  \
# 0  What do you find most difficult about ensuring...
# 1                                                NaN
#
#                                           Q44_Part_5  \
# 0  What do you find most difficult about ensuring...
# 1                                                NaN
#
#                                           Q44_Part_6  \
# 0  What do you find most difficult about ensuring...
# 1                                                NaN
#
#                                           Q45_Part_1  \
# 0  In what circumstances would you explore model ...
# 1                                                NaN
#
#                                           Q45_Part_2  \
# 0  In what circumstances would you explore model ...
# 1                                                NaN
#
#                                           Q45_Part_3  \
# 0  In what circumstances would you explore model ...
# 1                                                NaN
#
#                                           Q45_Part_4  \
# 0  In what circumstances would you explore model ...
# 1                                                NaN
#
#                                           Q45_Part_5  \
# 0  In what circumstances would you explore model ...
# 1                                                NaN
#
#                                           Q45_Part_6  \
# 0  In what circumstances would you explore model ...
# 1                                                NaN
#
#                                                  Q46  \
# 0  Approximately what percent of your data projec...
# 1                                                NaN
#
#                                           Q47_Part_1  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_2  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_3  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_4  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_5  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_6  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_7  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_8  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                           Q47_Part_9  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                          Q47_Part_10  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                          Q47_Part_11  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                          Q47_Part_12  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                          Q47_Part_13  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                          Q47_Part_14  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                          Q47_Part_15  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                          Q47_Part_16  \
# 0  What methods do you prefer for explaining and/...
# 1                                                NaN
#
#                                                  Q48  \
# 0  Do you consider ML models to be "black boxes" ...
# 1                                                NaN
#
#                                           Q49_Part_1  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_2  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_3  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_4  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_5  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_6  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_7  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_8  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                           Q49_Part_9  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                          Q49_Part_10  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                          Q49_Part_11  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                          Q49_Part_12  \
# 0  What tools and methods do you use to make your...
# 1                                                NaN
#
#                                       Q49_OTHER_TEXT  \
# 0  What tools and methods do you use to make your...
# 1                                                 -1
#
#                                           Q50_Part_1  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                           Q50_Part_2  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                           Q50_Part_3  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                           Q50_Part_4  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                           Q50_Part_5  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                           Q50_Part_6  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                           Q50_Part_7  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                           Q50_Part_8  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
#
#                                       Q50_OTHER_TEXT
# 0  What barriers prevent you from making your wor...
# 1                                                 -1

# %%
df_choice.columns = df_choice.iloc[0]
df_choice = df_choice.drop(0)
df_choice.head(2)
# Out:
# 0 Duration (in seconds) What is your gender? - Selected Choice  \
# 1                   710                                 Female
# 2                   434                                   Male
#
# 0 What is your gender? - Prefer to self-describe - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What is your age (# years)? In which country do you currently reside?  \
# 1                       45-49                  United States of America
# 2                       30-34                                 Indonesia
#
# 0 What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# 1                                    Doctoral degree
# 2                                  Bachelor’s degree
#
# 0 Which best describes your undergraduate major? - Selected Choice  \
# 1                                              Other
# 2                 Engineering (non-computer focused)
#
# 0 Select the title most similar to your current role (or most recent title if retired): - Selected Choice  \
# 1                                         Consultant
# 2                                              Other
#
# 0 Select the title most similar to your current role (or most recent title if retired): - Other - Text  \
# 1                                                 -1
# 2                                                  0
#
# 0 In what industry is your current employer/contract (or your most recent employer if retired)? - Selected Choice  \
# 1                                              Other
# 2                          Manufacturing/Fabrication
#
# 0 In what industry is your current employer/contract (or your most recent employer if retired)? - Other - Text  \
# 1                                                  0
# 2                                                 -1
#
# 0 How many years of experience do you have in your current role?  \
# 1                                                NaN
# 2                                               5-10
#
# 0 What is your current yearly compensation (approximate $USD)?  \
# 1                                                NaN
# 2                                          10-20,000
#
# 0 Does your current employer incorporate machine learning methods into their business?  \
# 1                                      I do not know
# 2                      No (we do not use ML methods)
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Analyze and understand data to influence product or business decisions  \
# 1  Analyze and understand data to influence produ...
# 2                                                NaN
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build and/or run a machine learning service that operationally improves my product or workflows  \
# 1  Build and/or run a machine learning service th...
# 2                                                NaN
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data  \
# 1  Build and/or run the data infrastructure that ...
# 2                                                NaN
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build prototypes to explore applying machine learning to new areas  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Do research that advances the state of the art of machine learning  \
# 1  Do research that advances the state of the art...
# 2                                                NaN
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - None of these activities are an important part of my role at work  \
# 1                                                NaN
# 2  None of these activities are an important part...
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Select any activities that make up an important part of your role at work: (Select all that apply) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What is the primary tool that you use at work or school to analyze data? (include text response) - Selected Choice  \
# 1  Cloud-based data software & APIs (AWS, GCP, Az...
# 2  Basic statistical software (Microsoft Excel, G...
#
# 0 What is the primary tool that you use at work or school to analyze data? (include text response) - Basic statistical software (Microsoft Excel, Google Sheets, etc.) - Text  \
# 1                                                 -1
# 2                                                  1
#
# 0 What is the primary tool that you use at work or school to analyze data? (include text response) - Advanced statistical software (SPSS, SAS, etc.) - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What is the primary tool that you use at work or school to analyze data? (include text response) - Business intelligence software (Salesforce, Tableau, Spotfire, etc.) - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What is the primary tool that you use at work or school to analyze data? (include text response) - Local or hosted development environments (RStudio, JupyterLab, etc.) - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What is the primary tool that you use at work or school to analyze data? (include text response) - Cloud-based data software & APIs (AWS, GCP, Azure, etc.) - Text  \
# 1                                                  0
# 2                                                 -1
#
# 0 What is the primary tool that you use at work or school to analyze data? (include text response) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Jupyter/IPython  \
# 1                                    Jupyter/IPython
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - RStudio  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - PyCharm  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Visual Studio Code  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - nteract  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Atom  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - MATLAB  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Visual Studio  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Notepad++  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Sublime Text  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Vim  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - IntelliJ  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Spyder  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - None  \
# 1                                                NaN
# 2                                               None
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Kaggle Kernels  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Google Colab  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Azure Notebook  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Domino Datalab  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Google Cloud Datalab  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Paperspace  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Floydhub  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Crestle  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - JupyterHub/Binder  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - None  \
# 1                                               None
# 2                                               None
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Google Cloud Platform (GCP)  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Amazon Web Services (AWS)  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Microsoft Azure  \
# 1                                    Microsoft Azure
# 2                                                NaN
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - IBM Cloud  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Alibaba Cloud  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - I have not used any cloud providers  \
# 1                                                NaN
# 2                I have not used any cloud providers
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Python  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - R  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - SQL  \
# 1                                                NaN
# 2                                                SQL
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Bash  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Java  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Javascript/Typescript  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Visual Basic/VBA  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - C/C++  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - MATLAB  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Scala  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Julia  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Go  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - C#/.NET  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - PHP  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Ruby  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - SAS/STATA  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - None  \
# 1                                               None
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What programming languages do you use on a regular basis? (Select all that apply) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What specific programming language do you use most often? - Selected Choice  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What specific programming language do you use most often? - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What programming language would you recommend an aspiring data scientist to learn first? - Selected Choice  \
# 1                                             Python
# 2                                             Python
#
# 0 What programming language would you recommend an aspiring data scientist to learn first? - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Scikit-Learn  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - TensorFlow  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Keras  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - PyTorch  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Spark MLlib  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - H20  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Fastai  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Mxnet  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Caret  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Xgboost  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - mlr  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Prophet  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - randomForest  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - lightgbm  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - catboost  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - CNTK  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Caffe  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - None  \
# 1                                               None
# 2                                               None
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What machine learning frameworks have you used in the past 5 years? (Select all that apply) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 Of the choices that you selected in the previous question, which ML library have you used the most? - Selected Choice  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Of the choices that you selected in the previous question, which ML library have you used the most? - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - ggplot2  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - Matplotlib  \
# 1                                         Matplotlib
# 2                                                NaN
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - Altair  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - Shiny  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - D3  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - Plotly  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - Bokeh  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What data visualization libraries or tools have you used in the past 5 years? (Select all that apply) - Selected Choice - Seaborn  \
# 1                                                NaN
# ...
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - Plot predicted vs. actual results  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - Print out a decision tree  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - Sensitivity analysis/perturbation importance  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - LIME functions  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - ELI5 functions  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - SHAP functions  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - None/I do not use these model explanation techniques  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What methods do you prefer for explaining and/or interpreting decisions that are made by ML models? (Select all that apply) - Other - Text  \
# 1                                                NaN
# 2                                                NaN
#
# 0 Do you consider ML models to be "black boxes" with outputs that are difficult or impossible to explain?  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Share code on Github or a similar code-sharing repository  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Share both data and code on Github or a similar code-sharing repository  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Share data, code, and environment using a hosted service (Kaggle Kernels, Google Colaboratory, Amazon SageMaker, etc.)  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Share data, code, and environment using containers (Docker, etc.)  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Share code, data, and environment using virtual machines (VirtualBox, etc.)  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Make sure the code is well documented  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Make sure the code is human-readable  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Define all random seeds  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Define relative rather than absolute file paths  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Include a text file describing all dependencies  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - None/I do not make my work easy for others to reproduce  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Other - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Too expensive  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Too time-consuming  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Requires too much technical knowledge  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Afraid that others will use my work without giving proper credit  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Not enough incentives to share my work  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - I had never considered making my work easier for others to reproduce  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - None of these reasons apply to me  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Other  \
# 1                                                NaN
# 2                                                NaN
#
# 0 What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Other - Text
# 1                                                 -1
# 2                                                 -1

# %% [markdown]
# ## Vamos explorar!

# %%
df_choice.describe()
# Out:
# 0      Duration (in seconds) What is your gender? - Selected Choice  \
# count                  23859                                  23859
# unique                  6522                                      4
# top                      142                                   Male
# freq                      31                                  19430
#
# 0      What is your gender? - Prefer to self-describe - Text  \
# count                                               23859
# unique                                                 67
# top                                                    -1
# freq                                                23780
#
# 0      What is your age (# years)? In which country do you currently reside?  \
# count                        23859                                     23859
# unique                          12                                        58
# top                          25-29                  United States of America
# freq                          6159                                      4716
#
# 0      What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# count                                               23438
# unique                                                  7
# top                                       Master’s degree
# freq                                                10855
#
# 0      Which best describes your undergraduate major? - Selected Choice  \
# count                                               22947
# unique                                                 13
# top         Computer science (software engineering, etc.)
# freq                                                 9430
#
# 0      Select the title most similar to your current role (or most recent title if retired): - Selected Choice  \
# count                                               22900
# unique                                                 21
# top                                               Student
# freq                                                 5253
#
# 0      Select the title most similar to your current role (or most recent title if retired): - Other - Text  \
# count                                               23859
# unique                                                863
# top                                                    -1
# freq                                                22537
#
# 0      In what industry is your current employer/contract (or your most recent employer if retired)? - Selected Choice  \
# count                                               21685
# unique                                                 19
# top                                  Computers/Technology
# freq                                                 5584
#
# 0      In what industry is your current employer/contract (or your most recent employer if retired)? - Other - Text  \
# count                                               23859
# unique                                                558
# top                                                    -1
# freq                                                22923
#
# 0      How many years of experience do you have in your current role?  \
# count                                               21101
# unique                                                 11
# top                                                   0-1
# freq                                                 5898
#
# 0      What is your current yearly compensation (approximate $USD)?  \
# count                                               20185
# unique                                                 19
# top     I do not wish to disclose my approximate yearl...
# freq                                                 4756
#
# 0      Does your current employer incorporate machine learning methods into their business?  \
# count                                               20669
# unique                                                  6
# top     We are exploring ML methods (and may one day p...
# freq                                                 4688
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Analyze and understand data to influence product or business decisions  \
# count                                                9532
# unique                                                  1
# top     Analyze and understand data to influence produ...
# freq                                                 9532
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build and/or run a machine learning service that operationally improves my product or workflows  \
# count                                                5481
# unique                                                  1
# top     Build and/or run a machine learning service th...
# freq                                                 5481
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data  \
# count                                                5233
# unique                                                  1
# top     Build and/or run the data infrastructure that ...
# freq                                                 5233
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build prototypes to explore applying machine learning to new areas  \
# count                                                7233
# unique                                                  1
# top     Build prototypes to explore applying machine l...
# freq                                                 7233
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Do research that advances the state of the art of machine learning  \
# count                                                4934
# unique                                                  1
# top     Do research that advances the state of the art...
# freq                                                 4934
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - None of these activities are an important part of my role at work  \
# count                                                3471
# unique                                                  1
# top     None of these activities are an important part...
# freq                                                 3471
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Other  \
# count                                                1192
# unique                                                  1
# top                                                 Other
# freq                                                 1192
#
# 0      Select any activities that make up an important part of your role at work: (Select all that apply) - Other - Text  \
# count                                               23859
# unique                                                399
# top                                                    -1
# freq                                                23315
#
# 0      What is the primary tool that you use at work or school to analyze data? (include text response) - Selected Choice  \
# count                                               19198
# unique                                                  6
# top     Local or hosted development environments (RStu...
# freq                                                 9554
#
# 0      What is the primary tool that you use at work or school to analyze data? (include text response) - Basic statistical software (Microsoft Excel, Google Sheets, etc.) - Text  \
# count                                               23859
# unique                                               1210
# top                                                    -1
# freq                                                19932
#
# 0      What is the primary tool that you use at work or school to analyze data? (include text response) - Advanced statistical software (SPSS, SAS, etc.) - Text  \
# count                                               23859
# unique                                                505
# top                                                    -1
# freq                                                22412
#
# 0      What is the primary tool that you use at work or school to analyze data? (include text response) - Business intelligence software (Salesforce, Tableau, Spotfire, etc.) - Text  \
# count                                               23859
# unique                                                482
# top                                                    -1
# freq                                                22726
#
# 0      What is the primary tool that you use at work or school to analyze data? (include text response) - Local or hosted development environments (RStudio, JupyterLab, etc.) - Text  \
# count                                               23859
# unique                                               3367
# top                                                    -1
# freq                                                14307
#
# 0      What is the primary tool that you use at work or school to analyze data? (include text response) - Cloud-based data software & APIs (AWS, GCP, Azure, etc.) - Text  \
# count                                               23859
# unique                                                550
# top                                                    -1
# freq                                                22507
#
# 0      What is the primary tool that you use at work or school to analyze data? (include text response) - Other - Text  \
# count                                               23859
# unique                                               1111
# top                                                    -1
# freq                                                22095
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Jupyter/IPython  \
# count                                               14010
# unique                                                  1
# top                                       Jupyter/IPython
# freq                                                14010
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - RStudio  \
# count                                                8503
# unique                                                  1
# top                                               RStudio
# freq                                                 8503
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - PyCharm  \
# count                                                7060
# unique                                                  1
# top                                               PyCharm
# freq                                                 7060
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Visual Studio Code  \
# count                                                5082
# unique                                                  1
# top                                    Visual Studio Code
# freq                                                 5082
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - nteract  \
# count                                                 127
# unique                                                  1
# top                                               nteract
# freq                                                  127
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Atom  \
# count                                                3906
# unique                                                  1
# top                                                  Atom
# freq                                                 3906
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - MATLAB  \
# count                                                5671
# unique                                                  1
# top                                                MATLAB
# freq                                                 5671
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Visual Studio  \
# count                                                5111
# unique                                                  1
# top                                         Visual Studio
# freq                                                 5111
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Notepad++  \
# count                                                7831
# unique                                                  1
# top                                             Notepad++
# freq                                                 7831
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Sublime Text  \
# count                                                5985
# unique                                                  1
# top                                          Sublime Text
# freq                                                 5985
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Vim  \
# count                                                4240
# unique                                                  1
# top                                                   Vim
# freq                                                 4240
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - IntelliJ  \
# count                                                3456
# unique                                                  1
# top                                              IntelliJ
# freq                                                 3456
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Spyder  \
# count                                                5339
# unique                                                  1
# top                                                Spyder
# freq                                                 5339
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - None  \
# count                                                 474
# unique                                                  1
# top                                                  None
# freq                                                  474
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Other  \
# count                                                1257
# unique                                                  1
# top                                                 Other
# freq                                                 1257
#
# 0      Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years? (Select all that apply) - Other - Text  \
# count                                               23859
# unique                                                494
# top                                                    -1
# freq                                                22667
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Kaggle Kernels  \
# count                                                6042
# unique                                                  1
# top                                        Kaggle Kernels
# freq                                                 6042
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Google Colab  \
# count                                                3532
# unique                                                  1
# top                                          Google Colab
# freq                                                 3532
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Azure Notebook  \
# count                                                1304
# unique                                                  1
# top                                        Azure Notebook
# freq                                                 1304
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Domino Datalab  \
# count                                                 119
# unique                                                  1
# top                                        Domino Datalab
# freq                                                  119
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Google Cloud Datalab  \
# count                                                1307
# unique                                                  1
# top                                  Google Cloud Datalab
# freq                                                 1307
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Paperspace  \
# count                                                 480
# unique                                                  1
# top                                            Paperspace
# freq                                                  480
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Floydhub  \
# count                                                 361
# unique                                                  1
# top                                              Floydhub
# freq                                                  361
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Crestle  \
# count                                                 138
# unique                                                  1
# top                                               Crestle
# freq                                                  138
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - JupyterHub/Binder  \
# count                                                4916
# unique                                                  1
# top                                     JupyterHub/Binder
# freq                                                 4916
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - None  \
# count                                                7597
# unique                                                  1
# top                                                  None
# freq                                                 7597
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Other  \
# count                                                 690
# unique                                                  1
# top                                                 Other
# freq                                                  690
#
# 0      Which of the following hosted notebooks have you used at work or school in the last 5 years? (Select all that apply) - Other - Text  \
# count                                               23859
# unique                                                314
# top                                                    -1
# freq                                                23358
#
# 0      Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Google Cloud Platform (GCP)  \
# count                                                4783
# unique                                                  1
# top                           Google Cloud Platform (GCP)
# freq                                                 4783
#
# 0      Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Amazon Web Services (AWS)  \
# count                                                7460
# unique                                                  1
# top                             Amazon Web Services (AWS)
# freq                                                 7460
#
# 0      Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Microsoft Azure  \
# count                                                3805
# unique                                                  1
# top                                       Microsoft Azure
# freq                                                 3805
#
# 0      Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - IBM Cloud  \
# count                                                1204
# unique                                                  1
# top                                             IBM Cloud
# freq                                                 1204
#
# 0      Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - Alibaba Cloud  \
# count                                                 549
# unique                                                  1
# top                                         Alibaba Cloud
# freq                                                  549
#
# 0      Which of the following cloud computing services have you used at work or school in the last 5 years? (Select all that apply) - Selected Choice - I have not used any cloud providers  \
# count                                                7103
# unique                                                  1
# ...
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Share data, code, and environment using containers (Docker, etc.)  \
# count                                                2680
# unique                                                  1
# top     Share data, code, and environment using contai...
# freq                                                 2680
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Share code, data, and environment using virtual machines (VirtualBox, etc.)  \
# count                                                1477
# unique                                                  1
# top     Share code, data, and environment using virtua...
# freq                                                 1477
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Make sure the code is well documented  \
# count                                                8052
# unique                                                  1
# top                 Make sure the code is well documented
# freq                                                 8052
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Make sure the code is human-readable  \
# count                                                7781
# unique                                                  1
# top                  Make sure the code is human-readable
# freq                                                 7781
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Define all random seeds  \
# count                                                4614
# unique                                                  1
# top                               Define all random seeds
# freq                                                 4614
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Define relative rather than absolute file paths  \
# count                                                3665
# unique                                                  1
# top       Define relative rather than absolute file paths
# freq                                                 3665
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Include a text file describing all dependencies  \
# count                                                4366
# unique                                                  1
# top       Include a text file describing all dependencies
# freq                                                 4366
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - None/I do not make my work easy for others to reproduce  \
# count                                                 985
# unique                                                  1
# top     None/I do not make my work easy for others to ...
# freq                                                  985
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Selected Choice - Other  \
# count                                                 244
# unique                                                  1
# top                                                 Other
# freq                                                  244
#
# 0      What tools and methods do you use to make your work easy to reproduce? (Select all that apply) - Other - Text  \
# count                                               23859
# unique                                                169
# top                                                    -1
# freq                                                23689
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Too expensive  \
# count                                                1371
# unique                                                  1
# top                                         Too expensive
# freq                                                 1371
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Too time-consuming  \
# count                                                6478
# unique                                                  1
# top                                    Too time-consuming
# freq                                                 6478
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Requires too much technical knowledge  \
# count                                                2674
# unique                                                  1
# top                 Requires too much technical knowledge
# freq                                                 2674
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Afraid that others will use my work without giving proper credit  \
# count                                                2104
# unique                                                  1
# top     Afraid that others will use my work without gi...
# freq                                                 2104
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Not enough incentives to share my work  \
# count                                                3569
# unique                                                  1
# top                Not enough incentives to share my work
# freq                                                 3569
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - I had never considered making my work easier for others to reproduce  \
# count                                                1059
# unique                                                  1
# top     I had never considered making my work easier f...
# freq                                                 1059
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - None of these reasons apply to me  \
# count                                                2500
# unique                                                  1
# top                     None of these reasons apply to me
# freq                                                 2500
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Selected Choice - Other  \
# count                                                 520
# unique                                                  1
# top                                                 Other
# freq                                                  520
#
# 0      What barriers prevent you from making your work even easier to reuse and reproduce? (Select all that apply) - Other - Text
# count                                               23859
# unique                                                409
# top                                                    -1
# freq                                                23428

# %% [markdown]
# ### Qual a porcentagem de dados faltantes?

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum() # conta a quantidade de missing
        mis_val_percent = 100 * df.isnull().sum() / len(df) # calcula a porcentagem
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1) # cria uma tabela
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'}) # renomeia as colunas
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1) # ordena os valores
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
missing_df = missing_values_table(df_choice)
missing_df.tail()
# Out:
# Your selected dataframe has 395 columns.
# There are 356 columns that have missing values.
#                                                     Missing Values  \
# 0
# How many years of experience do you have in you...            2758
# In what industry is your current employer/contr...            2174
# Select the title most similar to your current r...             959
# Which best describes your undergraduate major? ...             912
# What is the highest level of formal education t...             421
#
#                                                     % of Total Values
# 0
# How many years of experience do you have in you...               11.6
# In what industry is your current employer/contr...                9.1
# Select the title most similar to your current r...                4.0
# Which best describes your undergraduate major? ...                3.8
# What is the highest level of formal education t...                1.8

# %%
# Get the columns with > 50% missing
missing_columns = list(missing_df[missing_df['% of Total Values'] > 50].index)
print('We will remove %d columns.' % len(missing_columns))
# Out:
# We will remove 314 columns.

# %% [markdown]
# ### Qual a distribuição de genero dos respondentes?

# %%
fig, ax = plt.subplots(figsize=(12, 4))

sns.countplot(x=df_choice['What is your gender? - Selected Choice'], ax=ax, order =df_choice['What is your gender? - Selected Choice'].value_counts().index)
# Add labels to the plot
# plt.annotate('78% are Man, 19.4% are Woman and less than 2% are others diversityes', xy=(1, 14000))
plt.show()

# %% [markdown]
# ### Qual a distribuição de idade por genêro?

# %%
# Primeiro vamos verificar a distribuiçãode idade total

fig, ax = plt.subplots(figsize=(12, 4))

sns.countplot(x=df_choice['What is your age (# years)?'], ax=ax, order =df_choice['What is your age (# years)?'].value_counts().index)
# Add labels to the plot
# plt.annotate('78% are Man, 19.4% are Woman and less than 2% are others diversityes', xy=(1, 14000))
plt.show()

# %%
dist_gernder_age = pd.crosstab(df_choice['What is your gender? - Selected Choice'], df_choice['What is your age (# years)?']).apply(lambda r: r/r.sum(), axis=1)*100
dist_gernder_age
# Out:
# What is your age (# years)?                 18-21      22-24      25-29  \
# What is your gender? - Selected Choice
# Female                                  12.244389  25.536160  27.805486
# Male                                    12.913021  20.823469  25.501801
# Prefer not to say                        8.823529  17.647059  20.882353
# Prefer to self-describe                  8.860759  13.924051  22.784810
#
# What is your age (# years)?                 30-34      35-39     40-44  \
# What is your gender? - Selected Choice
# Female                                  15.511222   8.802993  4.264339
# Male                                    15.856922   9.547092  5.985589
# Prefer not to say                       15.294118  11.764706  7.058824
# Prefer to self-describe                 26.582278   6.329114  2.531646
#
# What is your age (# years)?                45-49     50-54     55-59  \
# What is your gender? - Selected Choice
# Female                                  2.643392  1.720698  1.022444
# Male                                    3.772517  2.563047  1.435924
# Prefer not to say                       5.000000  4.117647  1.176471
# Prefer to self-describe                 2.531646  1.265823  5.063291
#
# What is your age (# years)?                60-69     70-79       80+
# What is your gender? - Selected Choice
# Female                                  0.324190  0.099751  0.024938
# Male                                    1.317550  0.236747  0.046320
# Prefer not to say                       0.882353  0.882353  6.470588
# Prefer to self-describe                 1.265823  0.000000  8.860759

# %%
dist_gernder_age.plot.bar(rot=90, figsize=(10,8))
plt.legend()

# %% [markdown]
# ### Qual a distribuição de pais de origem?

# %%
df_choice.iloc[:,4].value_counts()
# Out:
# United States of America                                4716
# India                                                   4417
# China                                                   1644
# Other                                                   1036
# Russia                                                   879
# Brazil                                                   736
# Germany                                                  734
# United Kingdom of Great Britain and Northern Ireland     702
# Canada                                                   604
# France                                                   604
# Japan                                                    597
# Spain                                                    485
# I do not wish to disclose my location                    394
# Italy                                                    355
# Australia                                                330
# Turkey                                                   327
# Poland                                                   301
# Netherlands                                              270
# Ukraine                                                  252
# Nigeria                                                  208
# Mexico                                                   202
# South Korea                                              188
# Singapore                                                186
# Israel                                                   173
# Indonesia                                                171
# Switzerland                                              164
# Pakistan                                                 161
# Sweden                                                   155
# Portugal                                                 155
# South Africa                                             147
# Viet Nam                                                 144
# Colombia                                                 128
# Greece                                                   121
# Argentina                                                119
# Iran, Islamic Republic of...                             113
# Malaysia                                                 113
# Belgium                                                  111
# Bangladesh                                               107
# Denmark                                                  106
# Ireland                                                  101
# Egypt                                                     96
# Hungary                                                   93
# Belarus                                                   91
# Kenya                                                     85
# Peru                                                      81
# Finland                                                   79
# Romania                                                   79
# New Zealand                                               77
# Hong Kong (S.A.R.)                                        76
# Chile                                                     76
# Norway                                                    74
# Tunisia                                                   74
# Thailand                                                  73
# Philippines                                               73
# Czech Republic                                            72
# Morocco                                                   71
# Republic of Korea                                         71
# Austria                                                   62
# Name: In which country do you currently reside?, dtype: int64

# %%
# Primeiro vamos verificar a distribuiçãode idade total

fig, ax = plt.subplots(figsize=(20, 4))

sns.countplot(x=df_choice.iloc[:,4], ax=ax, order =df_choice.iloc[:,4].value_counts().index)
# Add labels to the plot
# plt.annotate('78% are Man, 19.4% are Woman and less than 2% are others diversityes', xy=(1, 14000))
plt.xticks(rotation=75)

plt.show()

# %%
dist_gernder_country = pd.crosstab(df_choice.iloc[:,1], df_choice.iloc[:,4]).apply(lambda r: r/r.sum(), axis=1)*100
dist_gernder_country
# Out:
# In which country do you currently reside?  Argentina  Australia   Austria  \
# What is your gender? - Selected Choice
# Female                                      0.299252   1.271820  0.174564
# Male                                        0.535255   1.399897  0.283067
# Prefer not to say                           0.588235   1.176471  0.000000
# Prefer to self-describe                     1.265823   3.797468  0.000000
#
# In which country do you currently reside?  Bangladesh   Belarus   Belgium  \
# What is your gender? - Selected Choice
# Female                                       0.324190  0.399002  0.199501
# Male                                         0.483788  0.386001  0.524961
# Prefer not to say                            0.000000  0.000000  0.000000
# Prefer to self-describe                      0.000000  0.000000  1.265823
#
# In which country do you currently reside?    Brazil    Canada     Chile  \
# What is your gender? - Selected Choice
# Female                                     1.620948  3.067332  0.249377
# Male                                       3.427689  2.444673  0.339681
# Prefer not to say                          0.588235  0.882353  0.000000
# Prefer to self-describe                    3.797468  3.797468  0.000000
#
# In which country do you currently reside?      China  Colombia  \
# What is your gender? - Selected Choice
# Female                                      6.658354  0.423940
# Male                                        6.881112  0.571282
# Prefer not to say                          11.176471  0.000000
# Prefer to self-describe                     2.531646  0.000000
#
# In which country do you currently reside?  Czech Republic   Denmark     Egypt  \
# What is your gender? - Selected Choice
# Female                                           0.099751  0.174564  0.548628
# Male                                             0.344828  0.494081  0.375708
# Prefer not to say                                0.000000  0.882353  0.294118
# Prefer to self-describe                          1.265823  0.000000  0.000000
#
# In which country do you currently reside?   Finland    France   Germany  \
# What is your gender? - Selected Choice
# Female                                     0.124688  2.593516  2.568579
# Male                                       0.360268  2.542460  3.196089
# Prefer not to say                          0.882353  1.470588  2.352941
# Prefer to self-describe                    1.265823  1.265823  2.531646
#
# In which country do you currently reside?    Greece  Hong Kong (S.A.R.)  \
# What is your gender? - Selected Choice
# Female                                     0.498753            0.249377
# Male                                       0.514668            0.324241
# Prefer not to say                          0.294118            0.882353
# Prefer to self-describe                    0.000000            0.000000
#
# In which country do you currently reside?   Hungary  \
# What is your gender? - Selected Choice
# Female                                     0.299252
# Male                                       0.416881
# Prefer not to say                          0.000000
# Prefer to self-describe                    0.000000
#
# In which country do you currently reside?  I do not wish to disclose my location  \
# What is your gender? - Selected Choice
# Female                                                                  2.069825
# Male                                                                    1.286670
# Prefer not to say                                                      16.470588
# Prefer to self-describe                                                 6.329114
#
# In which country do you currently reside?      India  Indonesia  \
# What is your gender? - Selected Choice
# Female                                     16.384040   0.822943
# Male                                       19.140504   0.694802
# Prefer not to say                          10.882353   0.588235
# Prefer to self-describe                     5.063291   1.265823
#
# In which country do you currently reside?  Iran, Islamic Republic of...  \
# What is your gender? - Selected Choice
# Female                                                         0.673317
# Male                                                           0.437468
# Prefer not to say                                              0.294118
# Prefer to self-describe                                        0.000000
#
# In which country do you currently reside?   Ireland    Israel     Italy  \
# What is your gender? - Selected Choice
# Female                                     0.324190  0.623441  1.172070
# Male                                       0.447761  0.746269  1.559444
# Prefer not to say                          0.294118  0.882353  0.882353
# Prefer to self-describe                    0.000000  0.000000  2.531646
#
# In which country do you currently reside?     Japan     Kenya  Malaysia  \
# What is your gender? - Selected Choice
# Female                                     0.847880  0.423940  0.748130
# Male                                       2.866701  0.344828  0.416881
# Prefer not to say                          1.764706  0.294118  0.588235
# Prefer to self-describe                    0.000000  0.000000  0.000000
#
# In which country do you currently reside?    Mexico   Morocco  Netherlands  \
# What is your gender? - Selected Choice
# Female                                     0.847880  0.423940     1.022444
# Male                                       0.854349  0.277921     1.158003
# Prefer not to say                          0.588235  0.000000     1.176471
# Prefer to self-describe                    0.000000  0.000000     0.000000
#
# In which country do you currently reside?  New Zealand   Nigeria    Norway  \
# What is your gender? - Selected Choice
# Female                                        0.349127  0.773067  0.224439
# Male                                          0.319094  0.910962  0.324241
# Prefer not to say                             0.294118  0.000000  0.588235
# Prefer to self-describe                       0.000000  0.000000  0.000000
#
# In which country do you currently reside?     Other  Pakistan      Peru  \
# What is your gender? - Selected Choice
# Female                                     4.114713  0.698254  0.274314
# Male                                       4.369532  0.684508  0.360268
# Prefer not to say                          5.294118  0.000000  0.000000
# Prefer to self-describe                    5.063291  0.000000  0.000000
#
# In which country do you currently reside?  Philippines    Poland  Portugal  \
# What is your gender? - Selected Choice
# Female                                        0.349127  1.346633  0.798005
# Male                                          0.293361  1.250643  0.633042
# Prefer not to say                             0.294118  1.176471  0.000000
# Prefer to self-describe                       1.265823  0.000000  0.000000
#
# In which country do you currently reside?  Republic of Korea   Romania  \
# What is your gender? - Selected Choice
# Female                                              0.199501  0.448878
# Male                                                0.319094  0.313948
# Prefer not to say                                   0.294118  0.000000
# Prefer to self-describe                             0.000000  0.000000
#
# In which country do you currently reside?     Russia  Singapore  South Africa  \
# What is your gender? - Selected Choice
# Female                                      2.817955   1.022444      0.723192
# Male                                        3.860010   0.725682      0.597015
# Prefer not to say                           2.352941   1.176471      0.294118
# Prefer to self-describe                    10.126582   0.000000      1.265823
#
# In which country do you currently reside?  South Korea     Spain    Sweden  \
# What is your gender? - Selected Choice
# Female                                        0.798005  1.870324  0.623441
# Male                                          0.792589  2.089552  0.648482
# Prefer not to say                             0.588235  1.176471  0.882353
# Prefer to self-describe                       0.000000  0.000000  1.265823
#
# In which country do you currently reside?  Switzerland  Thailand   Tunisia  \
# What is your gender? - Selected Choice
# Female                                        0.523691  0.299252  0.573566
# Male                                          0.720535  0.308801  0.257334
# Prefer not to say                             0.588235  0.294118  0.294118
# Prefer to self-describe                       1.265823  0.000000  0.000000
#
# In which country do you currently reside?    Turkey   Ukraine  \
# What is your gender? - Selected Choice
# Female                                     1.396509  0.773067
# Male                                       1.374164  1.121976
# Prefer not to say                          0.882353  0.882353
# Prefer to self-describe                    1.265823  0.000000
#
# In which country do you currently reside?  United Kingdom of Great Britain and Northern Ireland  \
# What is your gender? - Selected Choice
# Female                                                                              3.266833
# Male                                                                                2.851261
# Prefer not to say                                                                   3.529412
# Prefer to self-describe                                                             6.329114
#
# In which country do you currently reside?  United States of America  Viet Nam
# What is your gender? - Selected Choice
# Female                                                    26.982544  0.523691
# Male                                                      18.167782  0.627895
# Prefer not to say                                         22.647059  0.294118
# Prefer to self-describe                                   34.177215  0.000000

# %%
dist_gernder_country.plot.bar(rot=90, figsize=(10,8))

fontP = FontProperties()
fontP.set_size('small')
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Qual o grau de formação por genêro?

# %%
# Primeiro vamos verificar a distribuiçãode idade total

fig, ax = plt.subplots(figsize=(12, 4))

sns.countplot(x=df_choice.iloc[:,5], ax=ax, order =df_choice.iloc[:,5].value_counts().index)
plt.xticks(rotation=75)

# Add labels to the plot
# plt.annotate('78% are Man, 19.4% are Woman and less than 2% are others diversityes', xy=(1, 14000))
plt.show()

# %%
dist_gernder_scholar = pd.crosstab(df_choice.iloc[:,1], df_choice.iloc[:,5]).apply(lambda r: r/r.sum(), axis=1)*100
dist_gernder_scholar
# Out:
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  Bachelor’s degree  \
# What is your gender? - Selected Choice
# Female                                                                                                                   25.336039
# Male                                                                                                                     31.357042
# Prefer not to say                                                                                                        23.456790
# Prefer to self-describe                                                                                                  26.923077
#
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  Doctoral degree  \
# What is your gender? - Selected Choice
# Female                                                                                                                 15.876236
# Male                                                                                                                   13.947520
# Prefer not to say                                                                                                      16.975309
# Prefer to self-describe                                                                                                16.666667
#
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  I prefer not to answer  \
# What is your gender? - Selected Choice
# Female                                                                                                                         1.166624
# Male                                                                                                                           1.304143
# Prefer not to say                                                                                                             13.271605
# Prefer to self-describe                                                                                                        8.974359
#
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  Master’s degree  \
# What is your gender? - Selected Choice
# Female                                                                                                                 52.092315
# Male                                                                                                                   45.330749
# Prefer not to say                                                                                                      35.185185
# Prefer to self-describe                                                                                                41.025641
#
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  No formal education past high school  \
# What is your gender? - Selected Choice
# Female                                                                                                                                       0.405782
# Male                                                                                                                                         1.037029
# Prefer not to say                                                                                                                            4.629630
# Prefer to self-describe                                                                                                                      3.846154
#
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  Professional degree  \
# What is your gender? - Selected Choice
# Female                                                                                                                      2.307887
# Male                                                                                                                        2.613523
# Prefer not to say                                                                                                           2.469136
# Prefer to self-describe                                                                                                     1.282051
#
# What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  Some college/university study without earning a bachelor’s degree
# What is your gender? - Selected Choice
# Female                                                                                                                                                    2.815115
# Male                                                                                                                                                      4.409993
# Prefer not to say                                                                                                                                         4.012346
# Prefer to self-describe                                                                                                                                   1.282051

# %%
dist_gernder_scholar.plot.bar(rot=90, figsize=(10,8))
plt.legend()

# %% [markdown]
# ### Qual a distribuição de carreiras por genêro?

# %%
# Primeiro vamos verificar a distribuiçãode  total

fig, ax = plt.subplots(figsize=(12, 4))

sns.countplot(x=df_choice.iloc[:,7], ax=ax, order =df_choice.iloc[:,7].value_counts().index)
plt.xticks(rotation=75)

# Add labels to the plot
# plt.annotate('78% are Man, 19.4% are Woman and less than 2% are others diversityes', xy=(1, 14000))
plt.show()

# %%
pd.crosstab(df_choice.iloc[:,1], df_choice.iloc[:,7], margins=True, margins_name="Total")
# Out:
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Business Analyst  \
# What is your gender? - Selected Choice
# Female                                                                                                                154
# Male                                                                                                                  600
# Prefer not to say                                                                                                      13
# Prefer to self-describe                                                                                                 5
# Total                                                                                                                 772
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Chief Officer  \
# What is your gender? - Selected Choice
# Female                                                                                                              18
# Male                                                                                                               331
# Prefer not to say                                                                                                    9
# Prefer to self-describe                                                                                              2
# Total                                                                                                              360
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Consultant  \
# What is your gender? - Selected Choice
# Female                                                                                                          100
# Male                                                                                                            670
# Prefer not to say                                                                                                12
# Prefer to self-describe                                                                                           3
# Total                                                                                                           785
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  DBA/Database Engineer  \
# What is your gender? - Selected Choice
# Female                                                                                                                      21
# Male                                                                                                                       121
# Prefer not to say                                                                                                            3
# Prefer to self-describe                                                                                                      0
# Total                                                                                                                      145
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Analyst  \
# What is your gender? - Selected Choice
# Female                                                                                                            418
# Male                                                                                                             1476
# Prefer not to say                                                                                                  24
# Prefer to self-describe                                                                                             4
# Total                                                                                                            1922
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Engineer  \
# What is your gender? - Selected Choice
# Female                                                                                                              95
# Male                                                                                                               629
# Prefer not to say                                                                                                   11
# Prefer to self-describe                                                                                              2
# Total                                                                                                              737
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Journalist  \
# What is your gender? - Selected Choice
# Female                                                                                                                 1
# Male                                                                                                                  18
# Prefer not to say                                                                                                      1
# Prefer to self-describe                                                                                                0
# Total                                                                                                                 20
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Scientist  \
# What is your gender? - Selected Choice
# Female                                                                                                              687
# Male                                                                                                               3389
# Prefer not to say                                                                                                    50
# Prefer to self-describe                                                                                              11
# Total                                                                                                              4137
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Developer Advocate  \
# What is your gender? - Selected Choice
# Female                                                                                                                   12
# Male                                                                                                                    102
# Prefer not to say                                                                                                         3
# Prefer to self-describe                                                                                                   0
# Total                                                                                                                   117
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Manager  \
# What is your gender? - Selected Choice
# Female                                                                                                        43
# Male                                                                                                         536
# Prefer not to say                                                                                              8
# Prefer to self-describe                                                                                        3
# Total                                                                                                        590
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Marketing Analyst  \
# What is your gender? - Selected Choice
# Female                                                                                                                  30
# Male                                                                                                                    80
# Prefer not to say                                                                                                        5
# Prefer to self-describe                                                                                                  0
# Total                                                                                                                  115
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Not employed  \
# What is your gender? - Selected Choice
# Female                                                                                                            181
# Male                                                                                                              634
# Prefer not to say                                                                                                  22
# Prefer to self-describe                                                                                             5
# Total                                                                                                             842
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Other  \
# What is your gender? - Selected Choice
# Female                                                                                                     262
# Male                                                                                                      1035
# Prefer not to say                                                                                           18
# Prefer to self-describe                                                                                      7
# Total                                                                                                     1322
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Principal Investigator  \
# What is your gender? - Selected Choice
# Female                                                                                                                       10
# Male                                                                                                                         83
# Prefer not to say                                                                                                             3
# Prefer to self-describe                                                                                                       1
# Total                                                                                                                        97
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Product/Project Manager  \
# What is your gender? - Selected Choice
# Female                                                                                                                        55
# Male                                                                                                                         363
# Prefer not to say                                                                                                              6
# Prefer to self-describe                                                                                                        4
# Total                                                                                                                        428
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Research Assistant  \
# What is your gender? - Selected Choice
# Female                                                                                                                  126
# Male                                                                                                                    460
# Prefer not to say                                                                                                        10
# Prefer to self-describe                                                                                                   4
# Total                                                                                                                   600
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Research Scientist  \
# What is your gender? - Selected Choice
# Female                                                                                                                  196
# Male                                                                                                                    974
# Prefer not to say                                                                                                        18
# Prefer to self-describe                                                                                                   1
# Total                                                                                                                  1189
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Salesperson  \
# What is your gender? - Selected Choice
# Female                                                                                                            14
# Male                                                                                                              86
# Prefer not to say                                                                                                  1
# Prefer to self-describe                                                                                            1
# Total                                                                                                            102
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Software Engineer  \
# What is your gender? - Selected Choice
# Female                                                                                                                 359
# Male                                                                                                                  2733
# Prefer not to say                                                                                                       32
# Prefer to self-describe                                                                                                  6
# Total                                                                                                                 3130
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Statistician  \
# What is your gender? - Selected Choice
# Female                                                                                                             58
# Male                                                                                                              177
# Prefer not to say                                                                                                   1
# Prefer to self-describe                                                                                             1
# Total                                                                                                             237
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Student  \
# What is your gender? - Selected Choice
# Female                                                                                                      1011
# Male                                                                                                        4171
# Prefer not to say                                                                                             53
# Prefer to self-describe                                                                                       18
# Total                                                                                                       5253
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Total
# What is your gender? - Selected Choice
# Female                                                                                                    3851
# Male                                                                                                     18668
# Prefer not to say                                                                                          303
# Prefer to self-describe                                                                                     78
# Total                                                                                                    22900

# %%
dist_gernder_title = pd.crosstab(df_choice.iloc[:,1], df_choice.iloc[:,7]).apply(lambda r: r/r.sum(), axis=1)*100
dist_gernder_title
# Out:
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Business Analyst  \
# What is your gender? - Selected Choice
# Female                                                                                                           3.998961
# Male                                                                                                             3.214056
# Prefer not to say                                                                                                4.290429
# Prefer to self-describe                                                                                          6.410256
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Chief Officer  \
# What is your gender? - Selected Choice
# Female                                                                                                        0.467411
# Male                                                                                                          1.773088
# Prefer not to say                                                                                             2.970297
# Prefer to self-describe                                                                                       2.564103
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Consultant  \
# What is your gender? - Selected Choice
# Female                                                                                                     2.596728
# Male                                                                                                       3.589029
# Prefer not to say                                                                                          3.960396
# Prefer to self-describe                                                                                    3.846154
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  DBA/Database Engineer  \
# What is your gender? - Selected Choice
# Female                                                                                                                0.545313
# Male                                                                                                                  0.648168
# Prefer not to say                                                                                                     0.990099
# Prefer to self-describe                                                                                               0.000000
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Analyst  \
# What is your gender? - Selected Choice
# Female                                                                                                      10.854324
# Male                                                                                                         7.906578
# Prefer not to say                                                                                            7.920792
# Prefer to self-describe                                                                                      5.128205
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Engineer  \
# What is your gender? - Selected Choice
# Female                                                                                                        2.466892
# Male                                                                                                          3.369402
# Prefer not to say                                                                                             3.630363
# Prefer to self-describe                                                                                       2.564103
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Journalist  \
# What is your gender? - Selected Choice
# Female                                                                                                          0.025967
# Male                                                                                                            0.096422
# Prefer not to say                                                                                               0.330033
# Prefer to self-describe                                                                                         0.000000
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Data Scientist  \
# What is your gender? - Selected Choice
# Female                                                                                                        17.839522
# Male                                                                                                          18.154060
# Prefer not to say                                                                                             16.501650
# Prefer to self-describe                                                                                       14.102564
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Developer Advocate  \
# What is your gender? - Selected Choice
# Female                                                                                                             0.311607
# Male                                                                                                               0.546390
# Prefer not to say                                                                                                  0.990099
# Prefer to self-describe                                                                                            0.000000
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice   Manager  \
# What is your gender? - Selected Choice
# Female                                                                                                   1.116593
# Male                                                                                                     2.871223
# Prefer not to say                                                                                        2.640264
# Prefer to self-describe                                                                                  3.846154
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Marketing Analyst  \
# What is your gender? - Selected Choice
# Female                                                                                                            0.779018
# Male                                                                                                              0.428541
# Prefer not to say                                                                                                 1.650165
# Prefer to self-describe                                                                                           0.000000
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Not employed  \
# What is your gender? - Selected Choice
# Female                                                                                                       4.700078
# Male                                                                                                         3.396186
# Prefer not to say                                                                                            7.260726
# Prefer to self-describe                                                                                      6.410256
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice     Other  \
# What is your gender? - Selected Choice
# Female                                                                                                   6.803428
# Male                                                                                                     5.544247
# Prefer not to say                                                                                        5.940594
# Prefer to self-describe                                                                                  8.974359
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Principal Investigator  \
# What is your gender? - Selected Choice
# Female                                                                                                                 0.259673
# Male                                                                                                                   0.444611
# Prefer not to say                                                                                                      0.990099
# Prefer to self-describe                                                                                                1.282051
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Product/Project Manager  \
# What is your gender? - Selected Choice
# Female                                                                                                                  1.428200
# Male                                                                                                                    1.944504
# Prefer not to say                                                                                                       1.980198
# Prefer to self-describe                                                                                                 5.128205
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Research Assistant  \
# What is your gender? - Selected Choice
# Female                                                                                                             3.271877
# Male                                                                                                               2.464110
# Prefer not to say                                                                                                  3.300330
# Prefer to self-describe                                                                                            5.128205
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Research Scientist  \
# What is your gender? - Selected Choice
# Female                                                                                                             5.089587
# Male                                                                                                               5.217484
# Prefer not to say                                                                                                  5.940594
# Prefer to self-describe                                                                                            1.282051
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Salesperson  \
# What is your gender? - Selected Choice
# Female                                                                                                      0.363542
# Male                                                                                                        0.460681
# Prefer not to say                                                                                           0.330033
# Prefer to self-describe                                                                                     1.282051
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Software Engineer  \
# What is your gender? - Selected Choice
# Female                                                                                                            9.322254
# Male                                                                                                             14.640026
# Prefer not to say                                                                                                10.561056
# Prefer to self-describe                                                                                           7.692308
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice  Statistician  \
# What is your gender? - Selected Choice
# Female                                                                                                       1.506102
# Male                                                                                                         0.948147
# Prefer not to say                                                                                            0.330033
# Prefer to self-describe                                                                                      1.282051
#
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice    Student
# What is your gender? - Selected Choice
# Female                                                                                                   26.252921
# Male                                                                                                     22.343047
# Prefer not to say                                                                                        17.491749
# Prefer to self-describe                                                                                  23.076923

# %%
dist_gernder_title.plot.bar(rot=90, figsize=(14,5))
# plt.legend(loc=0)

fontP = FontProperties()
fontP.set_size('small')
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Qual a distribuição de experiência por genêro?

# %%
# Primeiro vamos verificar a distribuiçãode  total

fig, ax = plt.subplots(figsize=(12, 4))

sns.countplot(x=df_choice.iloc[:,11], ax=ax, order =df_choice.iloc[:,11].value_counts().index)
plt.xticks(rotation=75)

# Add labels to the plot
# plt.annotate('78% are Man, 19.4% are Woman and less than 2% are others diversityes', xy=(1, 14000))
plt.show()

# %%
dist_gernder_experience = pd.crosstab(df_choice.iloc[:,1], df_choice.iloc[:,11]).apply(lambda r: r/r.sum(), axis=1)*100
dist_gernder_experience
# Out:
# How many years of experience do you have in your current role?        0-1  \
# What is your gender? - Selected Choice
# Female                                                          34.191496
# Male                                                            26.806029
# Prefer not to say                                               23.046875
# Prefer to self-describe                                         21.126761
#
# How many years of experience do you have in your current role?        1-2  \
# What is your gender? - Selected Choice
# Female                                                          18.686723
# Male                                                            17.612750
# Prefer not to say                                               14.843750
# Prefer to self-describe                                         15.492958
#
# How many years of experience do you have in your current role?     10-15  \
# What is your gender? - Selected Choice
# Female                                                          5.814290
# Male                                                            7.426229
# Prefer not to say                                               8.203125
# Prefer to self-describe                                         5.633803
#
# How many years of experience do you have in your current role?     15-20  \
# What is your gender? - Selected Choice
# Female                                                          3.847266
# Male                                                            4.082693
# Prefer not to say                                               4.687500
# Prefer to self-describe                                         2.816901
#
# How many years of experience do you have in your current role?        2-3  \
# What is your gender? - Selected Choice
# Female                                                          11.715360
# Male                                                            12.300052
# Prefer not to say                                               10.546875
# Prefer to self-describe                                         21.126761
#
# How many years of experience do you have in your current role?     20-25  \
# What is your gender? - Selected Choice
# Female                                                          1.388487
# Male                                                            1.928741
# Prefer not to say                                               0.781250
# Prefer to self-describe                                         0.000000
#
# How many years of experience do you have in your current role?     25-30  \
# What is your gender? - Selected Choice
# Female                                                          0.520683
# Male                                                            0.871976
# Prefer not to say                                               0.781250
# Prefer to self-describe                                         0.000000
#
# How many years of experience do you have in your current role?       3-4  \
# What is your gender? - Selected Choice
# Female                                                          7.954874
# Male                                                            8.361725
# Prefer not to say                                               9.375000
# Prefer to self-describe                                         5.633803
#
# How many years of experience do you have in your current role?       30 +  \
# What is your gender? - Selected Choice
# Female                                                           0.433902
# Male                                                             0.970145
# Prefer not to say                                                1.953125
# Prefer to self-describe                                         12.676056
#
# How many years of experience do you have in your current role?       4-5  \
# What is your gender? - Selected Choice
# Female                                                          6.306046
# Male                                                            7.183692
# Prefer not to say                                               8.593750
# Prefer to self-describe                                         5.633803
#
# How many years of experience do you have in your current role?       5-10
# What is your gender? - Selected Choice
# Female                                                           9.140874
# Male                                                            12.455968
# Prefer not to say                                               17.187500
# Prefer to self-describe                                          9.859155

# %%
dist_gernder_experience.plot.bar(rot=90, figsize=(12,5))
plt.legend()

# %% [markdown]
# ### Qual a distribuição de salário?

# %%
# Primeiro vamos verificar a distribuiçãode  total

fig, ax = plt.subplots(figsize=(12, 4))

sns.countplot(x=df_choice.iloc[:,12], ax=ax, order =df_choice.iloc[:,12].value_counts().index)
plt.xticks(rotation=75)

# Add labels to the plot
# plt.annotate('78% are Man, 19.4% are Woman and less than 2% are others diversityes', xy=(1, 14000))
plt.show()

# %%
dist_gernder_compensation = pd.crosstab(df_choice.iloc[:,1], df_choice.iloc[:,12]).apply(lambda r: r/r.sum(), axis=1)*100
dist_gernder_compensation
# Out:
# What is your current yearly compensation (approximate $USD)?   0-10,000  \
# What is your gender? - Selected Choice
# Female                                                        23.212084
# Male                                                          21.714286
# Prefer not to say                                              9.387755
# Prefer to self-describe                                       16.901408
#
# What is your current yearly compensation (approximate $USD)?  10-20,000  \
# What is your gender? - Selected Choice
# Female                                                         9.032059
# Male                                                           9.720301
# Prefer not to say                                              9.795918
# Prefer to self-describe                                        5.633803
#
# What is your current yearly compensation (approximate $USD)?  100-125,000  \
# What is your gender? - Selected Choice
# Female                                                           3.637485
# Male                                                             4.288722
# Prefer not to say                                                3.265306
# Prefer to self-describe                                          5.633803
#
# What is your current yearly compensation (approximate $USD)?  125-150,000  \
# What is your gender? - Selected Choice
# Female                                                           2.681874
# Male                                                             2.652632
# Prefer not to say                                                1.632653
# Prefer to self-describe                                          1.408451
#
# What is your current yearly compensation (approximate $USD)?  150-200,000  \
# What is your gender? - Selected Choice
# Female                                                           1.418002
# Male                                                             2.424060
# Prefer not to say                                                2.857143
# Prefer to self-describe                                          1.408451
#
# What is your current yearly compensation (approximate $USD)?  20-30,000  \
# What is your gender? - Selected Choice
# Female                                                         6.134402
# Male                                                           7.103759
# Prefer not to say                                              3.673469
# Prefer to self-describe                                        8.450704
#
# What is your current yearly compensation (approximate $USD)?  200-250,000  \
# What is your gender? - Selected Choice
# Female                                                           0.154131
# Male                                                             0.980451
# Prefer not to say                                                1.224490
# Prefer to self-describe                                          1.408451
#
# What is your current yearly compensation (approximate $USD)?  250-300,000  \
# What is your gender? - Selected Choice
# Female                                                           0.215783
# Male                                                             0.403008
# Prefer not to say                                                0.000000
# Prefer to self-describe                                          1.408451
#
# What is your current yearly compensation (approximate $USD)?  30-40,000  \
# What is your gender? - Selected Choice
# Female                                                         5.425401
# Male                                                           5.612030
# Prefer not to say                                              2.448980
# Prefer to self-describe                                        5.633803
#
# What is your current yearly compensation (approximate $USD)?  300-400,000  \
# What is your gender? - Selected Choice
# Female                                                           0.123305
# Male                                                             0.270677
# Prefer not to say                                                1.224490
# Prefer to self-describe                                          0.000000
#
# What is your current yearly compensation (approximate $USD)?  40-50,000  \
# What is your gender? - Selected Choice
# Female                                                         4.870530
# Male                                                           4.763910
# Prefer not to say                                              4.897959
# Prefer to self-describe                                        4.225352
#
# What is your current yearly compensation (approximate $USD)?  400-500,000  \
# What is your gender? - Selected Choice
# Female                                                           0.000000
# Male                                                             0.138346
# Prefer not to say                                                0.000000
# Prefer to self-describe                                          0.000000
#
# What is your current yearly compensation (approximate $USD)?  50-60,000  \
# What is your gender? - Selected Choice
# Female                                                         4.623921
# Male                                                           4.559398
# Prefer not to say                                              4.081633
# Prefer to self-describe                                        1.408451
#
# What is your current yearly compensation (approximate $USD)?  500,000+  \
# What is your gender? - Selected Choice
# Female                                                        0.246609
# Male                                                          0.252632
# Prefer not to say                                             2.448980
# Prefer to self-describe                                       9.859155
#
# What is your current yearly compensation (approximate $USD)?  60-70,000  \
# What is your gender? - Selected Choice
# Female                                                         3.144266
# Male                                                           3.735338
# Prefer not to say                                              1.224490
# Prefer to self-describe                                        4.225352
#
# What is your current yearly compensation (approximate $USD)?  70-80,000  \
# What is your gender? - Selected Choice
# Female                                                         2.805179
# Male                                                           3.500752
# Prefer not to say                                              1.632653
# Prefer to self-describe                                        0.000000
#
# What is your current yearly compensation (approximate $USD)?  80-90,000  \
# What is your gender? - Selected Choice
# Female                                                         3.113440
# Male                                                           2.400000
# Prefer not to say                                              1.632653
# Prefer to self-describe                                        2.816901
#
# What is your current yearly compensation (approximate $USD)?  90-100,000  \
# What is your gender? - Selected Choice
# Female                                                          2.527744
# Male                                                            2.869173
# Prefer not to say                                               1.632653
# Prefer to self-describe                                         4.225352
#
# What is your current yearly compensation (approximate $USD)?  I do not wish to disclose my approximate yearly compensation
# What is your gender? - Selected Choice
# Female                                                                                                26.633785
# Male                                                                                                  22.610526
# Prefer not to say                                                                                     46.938776
# Prefer to self-describe                                                                               25.352113

# %%
dist_gernder_compensation.plot.bar(rot=90, figsize=(10,8))

fontP = FontProperties()
fontP.set_size('small')
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# # Referências

# %% [markdown]
# * https://www.kaggle.com/theoviel/kagglers-gender-pay-gap-salary-prediction/data?select=multipleChoiceResponses.csv
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
# * https://hbr.org/2016/06/visualizations-that-really-work
