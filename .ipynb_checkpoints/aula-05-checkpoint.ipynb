# %% [markdown]
# <img src='figures/logo.png'>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Vamos-preparar-os-dados!" data-toc-modified-id="Vamos-preparar-os-dados!-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Vamos preparar os dados!</a></span><ul class="toc-item"><li><span><a href="#Padronização:" data-toc-modified-id="Padronização:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Padronização:</a></span></li><li><span><a href="#Escalar-para-um-intervalo" data-toc-modified-id="Escalar-para-um-intervalo-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Escalar para um intervalo</a></span></li><li><span><a href="#Variáveis-dummy" data-toc-modified-id="Variáveis-dummy-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Variáveis dummy</a></span></li><li><span><a href="#Codificador-de-rotulos" data-toc-modified-id="Codificador-de-rotulos-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Codificador de rotulos</a></span></li><li><span><a href="#Outras-abordagens" data-toc-modified-id="Outras-abordagens-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Outras abordagens</a></span></li><li><span><a href="#Tratamento-de-dados-faltantes" data-toc-modified-id="Tratamento-de-dados-faltantes-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Tratamento de dados faltantes</a></span></li></ul></li><li><span><a href="#Leitura-dos-dados" data-toc-modified-id="Leitura-dos-dados-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Leitura dos dados</a></span><ul class="toc-item"><li><span><a href="#Existem-colunas-com-muitos-dados-faltantes-que-podem-ser-removidas?" data-toc-modified-id="Existem-colunas-com-muitos-dados-faltantes-que-podem-ser-removidas?-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Existem colunas com muitos dados faltantes que podem ser removidas?</a></span></li><li><span><a href="#Existem-dados-que-podem-ser-agrupados?--(ex.:-Prefere-não-responder-ou-Prefere-autodescrever;-Pais)" data-toc-modified-id="Existem-dados-que-podem-ser-agrupados?--(ex.:-Prefere-não-responder-ou-Prefere-autodescrever;-Pais)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Existem dados que podem ser agrupados?  (ex.: Prefere não responder ou Prefere autodescrever; Pais)</a></span></li><li><span><a href="#Como-tratar-os-dados-categóricos?" data-toc-modified-id="Como-tratar-os-dados-categóricos?-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Como tratar os dados categóricos?</a></span></li><li><span><a href="#Como-tratar-os-valores-em-range?" data-toc-modified-id="Como-tratar-os-valores-em-range?-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Como tratar os valores em range?</a></span></li></ul></li></ul></div>

# %% [markdown]
# * Aula 1: Metodologia de trabalho
# * Aula 2: Instalação de pacotes, nomenclatura e estrutura dos dados
# * Aula 3: Conceitos
# * Aula 4: Entendimento do negócio e dos dados
# * <font color='#990099'> **Aula 5: Preparação dos dados** </font>
# * Aula 6: Modelo e Avaliação

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Vamos preparar os dados!

# %% [markdown]
# Existem alguns passos comuns nessa etapa. Vamos ver alguns deles (não necessariamente usaremos todos aqui).

# %%
# dataframe de exemplo

from sklearn.datasets import load_wine
wine = load_wine()
df = pd.DataFrame(wine.data, columns=wine.feature_names)
df['target'] = pd.Series(wine.target)

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# ## Padronização:
#
# Alguns algoritmos tem desempenho melhor quando os dados estão padronizados. Isto é, cada coluna deve ter valor de média igual a zero e desvio padrão igual a 1. Isso pode ser facilmente feito assim:

# %%
from sklearn import preprocessing
std = preprocessing.StandardScaler()
df_std = std.fit_transform(df)

# %%
df_std
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  1.84791957,
#          1.01300893, -1.21394365],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  1.1134493 ,
#          0.96524152, -1.21394365],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.78858745,
#          1.39514818, -1.21394365],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.48544548,
#          0.28057537,  1.37386437],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.40069891,
#          0.29649784,  1.37386437],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.42894777,
#         -0.59516041,  1.37386437]])

# %% [markdown]
# ## Escalar para um intervalo
#
# Transformar os dados em um intervalo entre zero e um.

# %%
from sklearn import preprocessing
mms = preprocessing.MinMaxScaler()
df_mms = mms.fit_transform(df)

# %%
df_mms
# Out:
# array([[0.84210526, 0.1916996 , 0.57219251, ..., 0.97069597, 0.56134094,
#         0.        ],
#        [0.57105263, 0.2055336 , 0.4171123 , ..., 0.78021978, 0.55064194,
#         0.        ],
#        [0.56052632, 0.3201581 , 0.70053476, ..., 0.6959707 , 0.64693295,
#         0.        ],
#        ...,
#        [0.58947368, 0.69960474, 0.48128342, ..., 0.10622711, 0.39728959,
#         1.        ],
#        [0.56315789, 0.36561265, 0.54010695, ..., 0.12820513, 0.40085592,
#         1.        ],
#        [0.81578947, 0.66403162, 0.73796791, ..., 0.12087912, 0.20114123,
#         1.        ]])

# %% [markdown]
# ## Variáveis dummy
#
# Também conhecido como one-hot encoding, consiste em criar várias colunas para uma coluna de categorias, cada uma contendo 1 ou 0.

# %%
df = pd.DataFrame({'Col1': ['a', 'b', 'd'], 'Col2': ['b', 'a', 'c'],
                   'Col3': [1, 2, 3]})

# %%
df
# Out:
#   Col1 Col2  Col3
# 0    a    b     1
# 1    b    a     2
# 2    d    c     3

# %%
pd.get_dummies(df)
# Out:
#    Col3  Col1_a  Col1_b  Col1_d  Col2_a  Col2_b  Col2_c
# 0     1       1       0       0       0       1       0
# 1     2       0       1       0       1       0       0
# 2     3       0       0       1       0       0       1

# %% [markdown]
# ## Codificador de rotulos
#
# Uma alternativa à codificação dummy é a codificação de rótulos. Nesse caso, cada dado de categoria será atribuído a um número.

# %%
from sklearn import preprocessing
lab = preprocessing.LabelEncoder()
col1 = lab.fit_transform(df.Col1)

# %%
col1
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## Outras abordagens
#
# Existem várias outras soluções que podem ser encontradas aqui: https://contrib.scikit-learn.org/category_encoders/

# %% [markdown]
# ## Tratamento de dados faltantes
#
# Dados faltantes normalmente são uma complexidade a mais no projeto. Devemos primeiro entender o que é aquele dado, as vezes o dado faltante é uma informação, por exemplo, se estivermos falando de tamanhos de comodos, e um deles for tamanho da garagem, mas a casa não possui garagem, faz sentido que aquele dado esteja faltando, e logo, não faz sentindo que ele seja preenchido com determinadas técnicas.
#
# Em alguns casos, o dado está faltando por algum erro na tabela, ou esquecimento de marcação, então talvez faça sentido preencher com a média ou mediana da coluna.
#
# Dependendo da quantidade de dados faltantes na coluna, podemos decidir por removê-la. Vale fazer essa mesma análise por linha.

# %%
# removendo linhas com  valores faltantes
df.dropna(inplace=True)

# %%
# preenchendo os valores faltantes com a media
df.fillna(df.mean())

# %% [markdown]
# # Leitura dos dados

# %%
df_choice = pd.read_csv('data/multipleChoiceResponses.csv',low_memory=False)
df_choice.columns = df_choice.iloc[0]
df_choice = df_choice.drop(0)
df_choice.head(2)
# Out:
# 0 Duration (in seconds) What is your gender? - Selected Choice  \
# 1                   710                                 Female
# 2                   434                                   Male
#
# 0 What is your gender? - Prefer to self-describe - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 What is your age (# years)? In which country do you currently reside?  \
# 1                       45-49                  United States of America
# 2                       30-34                                 Indonesia
#
# 0 What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# 1                                    Doctoral degree
# 2                                  Bachelor’s degree
#
# 0 Which best describes your undergraduate major? - Selected Choice  \
# 1                                              Other
# ...

# %% [markdown]
# ## Existem colunas com muitos dados faltantes que podem ser removidas?

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum() # conta a quantidade de missing
        mis_val_percent = 100 * df.isnull().sum() / len(df) # calcula a porcentagem
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1) # cria uma tabela
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'}) # renomeia as colunas
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1) # ordena os valores
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns
missing_df = missing_values_table(df_choice);
missing_columns = list(missing_df[missing_df['% of Total Values'] > 80].index)
# Out:
# Your selected dataframe has 395 columns.
# There are 356 columns that have missing values.

# %%
df = df_choice.drop(list(missing_columns), axis=1)

# %%
# os outros vamos inputar

df = df.fillna('missing')

# %% [markdown]
# ## Existem dados que podem ser agrupados?  (ex.: Prefere não responder ou Prefere autodescrever; Pais)

# %% [markdown]
# Algumas categorias, que tenham baixa representatividade ou que possam ser muito parecidas, podem ser agrupadas.

# %%
# vamos agrupar a pergunta de genero 
df.iloc[:,1] = df.iloc[:,1].replace({'Prefer not to say': 'Others', 'Prefer to self-describe': 'Others'})

# %%
df.iloc[:, 4].unique()
# Out:
# array(['United States of America', 'Indonesia', 'India', 'Colombia',
#        'Chile', 'Turkey', 'Hungary', 'Ireland', 'France', 'Argentina',
#        'Japan', 'Nigeria', 'Spain', 'Other',
#        'Iran, Islamic Republic of...',
#        'United Kingdom of Great Britain and Northern Ireland', 'Poland',
#        'Kenya', 'Denmark', 'Netherlands', 'China', 'Sweden', 'Ukraine',
#        'Canada', 'Australia', 'Russia', 'Austria', 'Italy', 'Mexico',
#        'Germany', 'I do not wish to disclose my location', 'Singapore',
#        'Brazil', 'Switzerland', 'South Africa', 'South Korea', 'Malaysia',
#        'Hong Kong (S.A.R.)', 'Egypt', 'Tunisia', 'Portugal', 'Thailand',
#        'Morocco', 'Pakistan', 'Czech Republic', 'Romania', 'Israel',
#        'Philippines', 'Bangladesh', 'Belarus', 'Viet Nam', 'Belgium',
#        'New Zealand', 'Norway', 'Finland', 'Greece', 'Peru',
#        'Republic of Korea'], dtype=object)

# %%
allowed_vals = ['United States of America', 'India', 'China', 'Russia', 'Other', 'Brazil', \
               'Germany', 'United Kingdom of Great Britain and Northern Ireland',\
               'Canada', 'France', 'Japan']

# %%
df.loc[~df["In which country do you currently reside?"].isin(allowed_vals), "In which country do you currently reside?"] = "Others2"

# %%
df.iloc[:, 4].unique()
# Out:
# array(['United States of America', 'Others2', 'India', 'France', 'Japan',
#        'Other', 'United Kingdom of Great Britain and Northern Ireland',
#        'China', 'Canada', 'Russia', 'Germany', 'Brazil'], dtype=object)

# %%
df.head()
# Out:
# 0 Duration (in seconds) What is your gender? - Selected Choice  \
# 1                   710                                 Female
# 2                   434                                   Male
# 3                   718                                 Female
# 4                   621                                   Male
# 5                   731                                   Male
#
# 0 What is your gender? - Prefer to self-describe - Text  \
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
# 5                                                 -1
#
# 0 What is your age (# years)? In which country do you currently reside?  \
# 1                       45-49                  United States of America
# 2                       30-34                                   Others2
# ...

# %% [markdown]
# ## Como tratar os dados categóricos?

# %%
categoricas = ['What is your gender? - Selected Choice',\
               'In which country do you currently reside?',\
              'What is the highest level of formal education that you have attained or plan to attain within the next 2 years?',\
              'Which best describes your undergraduate major? - Selected Choice',\
               'Select the title most similar to your current role (or most recent title if retired): - Selected Choice',\
               'In what industry is your current employer/contract (or your most recent employer if retired)? - Selected Choice',
                ]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categoricas[1]
# Out:
# 'In which country do you currently reside?'

# %%
le = LabelEncoder()
# apply le on categorical feature columns
df[categoricas] = df[categoricas].apply(lambda col: le.fit_transform(col))
df[categoricas].head(10)
# Out:
# 0   What is your gender? - Selected Choice  \
# 1                                        0
# 2                                        1
# 3                                        0
# 4                                        1
# 5                                        1
# 6                                        1
# 7                                        1
# 8                                        1
# 9                                        1
# 10                                       1
#
# 0   In which country do you currently reside?  \
# 1                                          11
# 2                                           8
# 3                                          11
# 4                                          11
# 5                                           5
# 6                                           8
# 7                                           8
# 8                                           5
# 9                                           8
# ...

# %%
df.head()

# %% [markdown]
# ## Como tratar os valores em range?

# %%
intervalos = ['What is your age (# years)?',\
              'How many years of experience do you have in your current role?']
target = ['What is your current yearly compensation (approximate $USD)?']

# %%
df['What is your age (# years)?']
# Out:
# 1        45-49
# 2        30-34
# 3        30-34
# 4        35-39
# 5        22-24
#          ...
# 23855    45-49
# 23856    25-29
# 23857    22-24
# 23858    25-29
# 23859    25-29
# Name: What is your age (# years)?, Length: 23859, dtype: object

# %%
df['What is your age (# years)?']  = df['What is your age (# years)?'].str.extract(r'(?<=-)(\d+)').fillna(56).rename(columns={0:'Age'})

# %%
df['What is your age (# years)?']
# Out:
# 1        49
# 2        34
# 3        34
# 4        39
# 5        24
#          ..
# 23855    49
# 23856    29
# 23857    24
# 23858    29
# 23859    29
# Name: What is your age (# years)?, Length: 23859, dtype: object

# %%
df['How many years of experience do you have in your current role?']  = df['How many years of experience do you have in your current role?'].str.extract(r'(?<=-)(\d+)').fillna(1).rename(columns={0:'Experience'})

# %%
df['What is your current yearly compensation (approximate $USD)?']
# Out:
# 1            missing
# 2          10-20,000
# 3           0-10,000
# 4            missing
# 5           0-10,000
#             ...
# 23855    250-300,000
# 23856        missing
# 23857      10-20,000
# 23858        missing
# 23859        missing
# Name: What is your current yearly compensation (approximate $USD)?, Length: 23859, dtype: object

# %%
df = df[df['What is your current yearly compensation (approximate $USD)?'] != 'missing']

# %%
df['What is your current yearly compensation (approximate $USD)?']  = df['What is your current yearly compensation (approximate $USD)?'].str.extract(r'(?<=-)(\d+)').fillna(0).rename(columns={0:'Compensation'})

# %%
df['What is your current yearly compensation (approximate $USD)?']
# Out:
# 2         20
# 3         10
# 5         10
# 6          0
# 7         20
#         ...
# 23848      0
# 23850      0
# 23854     20
# 23855    300
# 23857     20
# Name: What is your current yearly compensation (approximate $USD)?, Length: 20185, dtype: object

# %%
df_modelo =  pd.concat([df[categoricas], df[intervalos], df[target]], axis=1)

# %%
df_modelo
# Out:
# 0      What is your gender? - Selected Choice  \
# 2                                           1
# 3                                           0
# 5                                           1
# 6                                           1
# 7                                           1
# ...                                       ...
# 23848                                       1
# 23850                                       0
# 23854                                       1
# 23855                                       1
# 23857                                       1
#
# 0      In which country do you currently reside?  \
# 2                                              8
# 3                                             11
# 5                                              5
# 6                                              8
# 7                                              8
# ...                                          ...
# 23848                                          4
# ...

# %%
df_modelo.to_csv('df_modelo.csv')
